# %% [markdown]
# Encapsulation adalah konsep OOP untuk menyembunyikan data di dalam class supaya tidak bisa diakses langsung dari luar, melainkan harus lewat method khusus

# %%
### Encapsulation with getter and setter methods
### Public, protected, private variable

class Person:
    def __init__(self, name, age):
        self.name=name  # Public variables
        self.age=age    # Public variables

def get_name(person):   # bisa diakses karena belum menggunakan encapsulation
    return person.name

person=Person("Henry",18)
get_name(person)
# Out:
# 'Henry'

# %%
dir(person) # age dan name
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name']

# %%
# Private can only be accessed inside class
class Person:
    def __init__(self, name, age, gender):
        self.__name=name    # Private variables use __ double underscore
        self.__age=age      # Private variables
        self.gender=gender  # Public variables
    
def get_name(person):
    return person.__name    # Tidak bisa diakses karena bersifat private tersembunyi. harus diakses didalam class

person=Person("Henry",18,"Male")
get_name(person)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 11
#       8     return person.__name    # Tidak bisa diakses karena bersifat private tersembunyi. harus diakses didalam class
#      10 person=Person("Henry",18,"Male")
# ---> 11 get_name(person)
#
# Cell In[10], line 8, in get_name(person)
#       7 def get_name(person):
# ----> 8     return person.__name
#
# AttributeError: 'Person' object has no attribute '__name'

# %%
dir(person) # Tidak ada age dan name karena sudah bersifat private.
# Out:
# ['_Person__age',
#  '_Person__name',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'gender']

# %%
# Protected can only be accessed in derived class
class Person:
    def __init__(self, name, age, gender):
        self._name=name     # protected variables use _ single underscore
        self._age=age       # protected variables
        self.gender=gender  # Public variables
    
class Employee(Person):
    def __init__(self, name, age, gender):
        super().__init__(name, age, gender)

employee=Employee("Henry", 17, "Male")
print(employee._name)
# Out:
# Henry

# %%
## Encapsulation with getter and setter

class Person:
    def __init__(self, name, age):
        self.__name=name    # Private variables
        self.__age=age      # Private variables

    ## Getter methods for name inside the class
    def get_name(self):
        return self.__name
    
    ## Setter methods for name for changes any value
    def set_name(self, name):
        self.__name=name

    ## Getter method for age
    def get_age(self):
        return self.__age
    
    ## Setter method for age

    def set_age(self, age):
        if age > 0:
            self.__age= age
        else:
            print("Age cannot negative")

person=Person("Henry",17)

## Access and modified private variable using getter and setter

print(person.get_name())
print(person.get_age())

person.set_age(45)
print(person.get_age())

print(person.set_age(-5))
# Out:
# Henry
# 17
# 45
# Age cannot negative
# None
