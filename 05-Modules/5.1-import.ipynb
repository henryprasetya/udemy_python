# %% [markdown]
# Modul berfungsi untuk mengorganisasi dan memakai ulang package yang banyak pada sebuah code.

# %%
import math
math.sqrt(16) #akar
# Out:
# 4.0

# %%
from math import sqrt,pi #ambil fungsi sqrt dan pi dari function math
print(sqrt(16))
print(sqrt(25))
print(pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %%
import numpy as np #np bersifat sebagai alias jadi tidak perlu panggil numpy cukup dengan np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import * # * bersifat import/akses semua fungsi tanpa terkecuali pada math
print (sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
from package.maths import addition #package maths yang berisikan fungsi addition harus berada dalam folder yang sama
addition(2,3)
# Out:
# 5

# %%
from package import maths
maths.addition(2,3)
# Out:
# 5
