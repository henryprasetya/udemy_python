# %%
## Create a new directory
import os

new_directory="package"
os.mkdir(new_directory)
print(f"Directory '{new_directory}' create")
# Out:
# Directory 'package' create

# %%
## Listing files and directories

item=os.listdir('.') # '.' berfungsi untuk menentukan lokasi saat ini
print(item)
# Out:
# ['6.1-fileoperation.ipynb', 'example.txt', 'example.bin', 'destination.txt', '6.2-filepath.ipynb', 'package']

# %%
### Joining Paths

dir_name="folder"
file_name="file.txt"
full_path=os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
dir_name="folder"
file_name="file.txt"
full_path=os.path.join(os.getcwd(),dir_name,file_name) #os.getcwd() untuk lokasi path secara utuh
print(full_path)
# Out:
# h:\My Drive\01_PROJECTS\udemy\data engineer\python\6-File Handling\folder\file.txt

# %%
## Cek file dalam sebuah path ada atau tidak

path='example1.txt'
if os.path.exists(path):
    print(f"The path '{path}' exists")
else:
    print(f"The path '{path}' does not exists")
# Out:
# The path 'example1.txt' does not exists

# %%
# Cek path is a file or directory

import os

path = 'example.txt'
if os.path.isfile(path):
    print(f"The path '{path}' is a file")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory")
else:
    print(f"The path '{path}' is neither a file nor a directory")
# Out:
# The path 'example.txt' is a file

# %%
## Getting the absolute path

relative_path='example.txt'
absolute_path=os.path.abspath(relative_path)
print(absolute_path)
# Out:
# h:\My Drive\01_PROJECTS\udemy\data engineer\python\6-File Handling\example.txt
