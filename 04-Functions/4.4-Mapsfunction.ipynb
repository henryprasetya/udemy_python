# %%
def square(x):
    return x*x

square(4)
# Out:
# 16

# %%
numbers=[1,2,3,4,5,6,7,8]

list(map(square,numbers))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
## Lambda function with map
## Contoh angka*pangkat

numbers=[1,2,3,4,5,6,7,8]
list(map(lambda x:x*x,numbers))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
## Map multiple iterables

numbers1=[1,2,3]
numbers2=[4,5,6]

added_numbers=list(map(lambda x,y:x+y,numbers1,numbers2))
print(added_numbers)
# Out:
# [5, 7, 9]

# %%
## Map() to converst list of strings to integers
# use map to convert strings to integers

str_numbers = ['1', '2', '3', '4', '5']
int_numbers = list(map(int, str_numbers))

print(int_numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
words=['apel','pisang','ceri']
upper_word=list(map(str.upper,words))

print(upper_word)
# Out:
# ['APEL', 'PISANG', 'CERI']

# %%
def get_name(person):
    return person['name']

people=[
    {'name':'Henry','age':28},
    {'name':'Jack','age':33}
]

list(map(get_name,people))
# Out:
# ['Henry', 'Jack']

# %% [markdown]
# Kesimpulan
#
# Fungsi map() adalah alat yang ampuh untuk menerapkan transformasi pada struktur data iterable (yang bisa diulang). Fungsi ini dapat digunakan dengan fungsi biasa, fungsi lambda, dan bahkan beberapa iterable sekaligus, menyediakan pendekatan yang serbaguna untuk pemrosesan data dengan Python. Dengan memahami dan memanfaatkan map(), Anda dapat menulis kode yang lebih efisien dan mudah dibaca.
