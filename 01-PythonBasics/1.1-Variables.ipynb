# %%
a=100

# %%
## Declaring and Assigning Variables

age=28
height=6.1
name="Henry"
is_student=True

## Printing Variables

print("age :",age)
print("Height :",height)
print("Name :",name)
# Out:
# age : 28
# Height : 6.1
# Name : Henry

# %%
## Naming Convention
## Variable names should be descriptive
## They must start with a letter or and '_' and contain letter, numbers and underscores
## Variables name are case sensitive

#valid variable name
first_name="Henry"
last_name="Prasetya"

# %%
## Invalid variables name

#2age=30
#first-name="Henry"
##@name="Henry"
# Out:
#   Cell In[7], line 5
#     @name="Henry"
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
## Case sensitivity
name="Henry"
Name="PRasetya"

name==Name
# Out:
# False

# %%
## Understading Vaariable types
## Python is dynamically type, type of variable is determined at runtime

age=28
height=165.5 #float
name="Henry" #string
is_student=True #boolean

print(type(name))
# Out:
# <class 'str'>

# %%
## Type Checking and Converstion

type(height)
# Out:
# float

# %%
age=25
print(type(age))

#type converstion
age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
age='25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
name="Henry"
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 name="Henry"
# ----> 2 int(name)
#
# ValueError: invalid literal for int() with base 10: 'Henry'

# %%
height=6.0
type(height)
# Out:
# float

# %%
float(int(height))
# Out:
# 6.0

# %%
## Dynamic Typing // its Important
## Python allow the type of variable to change as the program executes
var=10 #int
print(var,type(var))

var="Hello"
print(var,type(var))

var=3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
## Input

age=int(input("What is the age"))
print(age,type(age))
# Out:
# 23 <class 'int'>
